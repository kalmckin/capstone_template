# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
# place = "1045  2ND  AVE S, Tennessee"
# location = geolocator.geocode(place)
# print(location)

# %%
sales_by_zip = pd.read_csv("../Data/sales_data_with_addresses.csv")

# %%
sales_by_zip.head()
# Out:
#    Source.Name  Type  Zone        Parcel ID                        Land Use  \
# 0         2018  comm   NaN  018 12 0 079.00  ONE STORY GENERAL RETAIL STORE
# 1         2018  comm   NaN  019 13 0 052.00             LIGHT MANUFACTURING
# 2         2018  comm   NaN  022 00 0 235.00          VACANT COMMERCIAL LAND
# 3         2018  comm   NaN  026 00 0 150.00                     HOTEL/MOTEL
# 4         2018  comm   NaN  026 01 0 096.00                          CHURCH
#
#           Property Address Suite/ Condo   #   Property City   Sale Date  \
# 0          609  N MAIN  ST              NaN  GOODLETTSVILLE  11/21/2018
# 1           205  DEPOT  ST              NaN  GOODLETTSVILLE  12/10/2018
# 2    0  WHITES CREEK  PIKE              NaN         JOELTON  11/21/2018
# 3      909  CONFERENCE  DR              NaN  GOODLETTSVILLE  11/30/2018
# 4  144   LONG HOLLOW  PIKE              NaN  GOODLETTSVILLE   2/20/2018
#
#    Sale Price   Legal Reference Sold As Vacant  \
# ...

# %%
sales_by_zip['address_with_city'] = sales_by_zip["Property Address"] + " , " + sales_by_zip["Property City"] + " , " + "TN"

# %%
sales_by_zip.head()
# Out:
#    Source.Name  Type  Zone        Parcel ID                        Land Use  \
# 0         2018  comm   NaN  018 12 0 079.00  ONE STORY GENERAL RETAIL STORE
# 1         2018  comm   NaN  019 13 0 052.00             LIGHT MANUFACTURING
# 2         2018  comm   NaN  022 00 0 235.00          VACANT COMMERCIAL LAND
# 3         2018  comm   NaN  026 00 0 150.00                     HOTEL/MOTEL
# 4         2018  comm   NaN  026 01 0 096.00                          CHURCH
#
#           Property Address Suite/ Condo   #   Property City   Sale Date  \
# 0          609  N MAIN  ST              NaN  GOODLETTSVILLE  11/21/2018
# 1           205  DEPOT  ST              NaN  GOODLETTSVILLE  12/10/2018
# 2    0  WHITES CREEK  PIKE              NaN         JOELTON  11/21/2018
# 3      909  CONFERENCE  DR              NaN  GOODLETTSVILLE  11/30/2018
# 4  144   LONG HOLLOW  PIKE              NaN  GOODLETTSVILLE   2/20/2018
#
#    Sale Price   Legal Reference Sold As Vacant  \
# ...

# %%
# geolocator = Nominatim(user_agent="myApp")

# sales_by_zip[['location_lat', 'location_long']] = sales_by_zip['address_with_city'].apply(geolocator.geocode).apply(lambda x: pd.Series([x.latitude, x.longitude], index=['location_lat', 'location_long']))

# %%
from geopy.extra.rate_limiter import RateLimiter

# %%
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
sales_by_zip['location'] = sales_by_zip['address_with_city'].apply(geocode)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('618 B  HAMILTON  AVE , NASHVILLE , TN',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\kalmc\anaconda3\lib\site-packages\urllib3\connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\kalmc\anaconda3\lib\site-packages\urllib3\util\connection.py", line 95, in create_connection
#     raise err
#   File "C:\Users\kalmc\anaconda3\lib\site-packages\urllib3\util\connection.py", line 85, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kalmc\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\kalmc\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
# ...
